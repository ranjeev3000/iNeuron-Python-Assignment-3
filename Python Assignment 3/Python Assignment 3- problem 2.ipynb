# %% [markdown]
# ## Python Assignment 3: problem 2

# %% [markdown]
# # part 1

# %%
lst1 = ['X','Y','Z']   #Create a list

# %%
ABC = [a*i for a in lst1 for i in range(1,5)]      #list comprehension for two loops of "a" and "i"
ABC   #Peint ABC
# Out:
# ['X', 'XX', 'XXX', 'XXXX', 'Y', 'YY', 'YYY', 'YYYY', 'Z', 'ZZ', 'ZZZ', 'ZZZZ']

# %% [markdown]
# # part 2

# %%
lst2 = [i*a for a in lst1 for i in range(1,5)]

# %%
lst2
# Out:
# ['X', 'XX', 'XXX', 'XXXX', 'Y', 'YY', 'YYY', 'YYYY', 'Z', 'ZZ', 'ZZZ', 'ZZZZ']

# %% [markdown]
# # part 3

# %%
lst3 = [[x+y] for x in range(2,5) for y in range(3)]

# %%
lst3
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %% [markdown]
# # part 4

# %%
lsst = [2,3,4,5]
[(a,b,c,d) for a in range (2,6) for b in range (3,7) for c in range (4,8) for d in range (5,9)]
# Out:
# [(2, 3, 4, 5),
#  (2, 3, 4, 6),
#  (2, 3, 4, 7),
#  (2, 3, 4, 8),
#  (2, 3, 5, 5),
#  (2, 3, 5, 6),
#  (2, 3, 5, 7),
#  (2, 3, 5, 8),
#  (2, 3, 6, 5),
#  (2, 3, 6, 6),
#  (2, 3, 6, 7),
#  (2, 3, 6, 8),
#  (2, 3, 7, 5),
#  (2, 3, 7, 6),
#  (2, 3, 7, 7),
#  (2, 3, 7, 8),
#  (2, 4, 4, 5),
#  (2, 4, 4, 6),
#  (2, 4, 4, 7),
#  (2, 4, 4, 8),
#  (2, 4, 5, 5),
#  (2, 4, 5, 6),
#  (2, 4, 5, 7),
#  (2, 4, 5, 8),
#  (2, 4, 6, 5),
#  (2, 4, 6, 6),
#  (2, 4, 6, 7),
#  (2, 4, 6, 8),
#  (2, 4, 7, 5),
#  (2, 4, 7, 6),
#  (2, 4, 7, 7),
#  (2, 4, 7, 8),
#  (2, 5, 4, 5),
#  (2, 5, 4, 6),
#  (2, 5, 4, 7),
#  (2, 5, 4, 8),
#  (2, 5, 5, 5),
#  (2, 5, 5, 6),
#  (2, 5, 5, 7),
#  (2, 5, 5, 8),
#  (2, 5, 6, 5),
#  (2, 5, 6, 6),
#  (2, 5, 6, 7),
#  (2, 5, 6, 8),
#  (2, 5, 7, 5),
#  (2, 5, 7, 6),
#  (2, 5, 7, 7),
#  (2, 5, 7, 8),
#  (2, 6, 4, 5),
#  (2, 6, 4, 6),
#  (2, 6, 4, 7),
#  (2, 6, 4, 8),
#  (2, 6, 5, 5),
#  (2, 6, 5, 6),
#  (2, 6, 5, 7),
#  (2, 6, 5, 8),
#  (2, 6, 6, 5),
#  (2, 6, 6, 6),
# ...

# %% [markdown]
# # Part 5

# %%
[(x,y) for x in [1,2,3] for y in [1,2,3]]
# Out:
# [(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)]
